# %% [markdown]
# ## **House Prices - Advanced Regression Techniques**

# %% [markdown]
# # **Что входит в успешное решение:**
#
# 1. Подготовка и тщательный анализ данных.
# Разбить данные на training sample и validation sample.
# Проанализировать признаки. Отобрать те, которые лично вам кажутся наиболее важными. Посмотреть на их распределение (в том числе на попарные). Посмотреть на совместное распределение целевой переменной и выбранных признаков.
# Сформулировать гипотезы о том, какие сочетания признаков могут быть полезны. Добавить их (если придумаете).  Подсказка (одна из идей если решаете задачу предсказания цен на дома): отрисуйте выборку на карте, посчитайте расстояние до важных объектов в этом городе, посчитайте статистики по районам и по ближайшим объектам (не забудьте, что эти статистики нужно считать по обучающей выборке!).
# 2. Выбор алгоритма и его гиперпараметров.
# Обосновать выбор алгоритма/его конкретной реализации, если их несколько
# Если гиперпараметры подбирались, нужно обосновать необходимость в этом.
# Учесть логику работы алгоритма. Не нужно делать one-hot encoding категориальных признаков при использовании CatBoostRegressor, нужно масштабировать признаки при работе с метрическими методами etc.
# 3. Грамотный подход к обучению модели.
# Когда отправляете решение на Kaggle, необходимо сделать либо коммит на GitHub, либо сохранение копии ноутбука с датой (так, чтобы вы могли сопоставить ноутбуки посылкам - это необходимо для воспроизводимости решения).
# Желательно также сделать чекпоинт модели, с той же целью (как это сделать, узнаем на занятии)
# 4. Финальный анализ.
# Проанализировать важности признаков.
# Соотнести полученную из модели важность признаков с гипотезами из пункта 1, сделать выводы.
# 5. Презентация результатов
# Рассказать о работе своей команды: кто за что отвечал, какие были сложности, какие идеи приводили к успеху.
# Максимально объяснить принятые решения: от доли валидационной выборки, до выбора гиперпараметров.
# Включить в презентацию графики и интересные визуализации из предварительного и финального анализа.
# Рассказать о вычислительном аспекте: где обучали, сколько это заняло времени; если удалось ускорить, то каким образом.
# Вставьте обязательно слайд с тем, какое место в общем рейтинге удалось занять Вашей команде (скриншот).

# %% [markdown]
# # **File descriptions:**
#
#
# *   **train.csv** - the training set
# *   **test.csv** - the test set
# *   **data_description.txt** - full description of each column, originally prepared by Dean De Cock but lightly edited to match the column names used here
# *   **sample_submission.csv** - a benchmark submission from a linear regression on year and month of sale, lot square footage, and number of bedrooms

# %% [markdown]
# # **Data fields:**
#
# SalePrice - цена продажи недвижимости в долларах. Это целевая переменная, которую вы пытаетесь предсказать.
#
# MSSubClass: Класс здания
#
# MSZoning: Общая зональная классификация
#
# LotFrontage: Линейные футы улицы, примыкающей к собственности
#
# LotArea: Площадь участка в квадратных футах
#
# Street: Тип подъездной дороги
#
# Alley: Тип подъезда к аллее
#
# LotShape: Общая форма участка
#
# LandContour: Ровность участка
#
# Utilities: Тип доступных коммунальных услуг
#
# LotConfig: Конфигурация участка
#
# LandSlope: Уклон участка
#
# Neighborhood: Физическое местоположение в черте города Эймс
#
# Condition1:Близость к главной дороге или железной дороге
#
# Condition2: Близость к главной дороге или железной дороге (при наличии второй)
#
# BldgType: Тип жилища
#
# HouseStyle: Стиль жилища
#
# OverallQual: Общее качество материалов и отделки
#
# OverallCond: Общая оценка состояния
#
# YearBuilt: Дата первоначального строительства
#
# YearRemodAdd: Дата перестройки
#
# RoofStyle: Тип крыши
#
# RoofMatl: Материал крыши
#
# Exterior1st: Внешнее покрытие дома
#
# Exterior2nd: Внешнее покрытие дома (если используется более одного материала)
#
# MasVnrType: Тип шпона каменной кладки
#
# MasVnrArea: Площадь кладки шпона в квадратных футах
#
# ExterQual: Качество наружного материала
#
# ExterCond: Текущее состояние материала на внешней стороне
#
# Foundation: Тип фундамента
#
# BsmtQual: Высота подвала
#
# BsmtCond: Общее состояние подвала
#
# BsmtExposure: стены подвала на уровне выхода или сада
#
# BsmtFinType1: Качество отделанной площади подвала
#
# BsmtFinSF1: Законченные квадратные футы типа 1
#
# BsmtFinType2: Качество второй готовой площади (если есть)
#
# BsmtFinSF2: Тип 2 законченных квадратных футов
#
# BsmtUnfSF: Незавершенные квадратные футы площади подвала
#
# TotalBsmtSF: Общая площадь подвала в квадратных футах
#
# Heating: Тип отопления
#
# HeatingQC: Качество и состояние отопления
#
# CentralAir: Центральное кондиционирование
#
# Electrical: Электрическая система
#
# 1stFlrSF: квадратные футы первого этажа
#
# 2ndFlrSF: квадратные футы второго этажа
#
# LowQualFinSF: Низкокачественная отделка квадратных футов (все этажи)
#
# GrLivArea: Жилая площадь над уровнем земли (на земле) квадратных футов
#
# BsmtFullBath: Полные ванные комнаты в подвале
#
# BsmtHalfBath: Половина ванной комнаты в подвале
#
# FullBath: Полные ванные комнаты над уровнем земли
#
# HalfBath: Половина ванны выше уровня
#
# Bedroom: Количество спален выше уровня подвала
#
# Kitchen: Количество кухонь
#
# KitchenQual: Качество кухни
#
# TotRmsAbvGrd: Общее количество комнат над уровнем пола (не включает ванные
# комнаты)
#
# Functional: Оценка функциональности дома
#
# Fireplaces: Количество каминов
#
# FireplaceQu: Качество камина
#
# GarageType: Расположение гаража
#
# GarageYrBlt: Год постройки гаража
#
# GarageFinish: Внутренняя отделка гаража
#
# GarageCars: Размер гаража в машино-местах
#
# GarageArea: Площадь гаража в квадратных футах
#
# GarageQual: Качество гаража
#
# GarageCond: Состояние гаража
#
# PavedDrive: Мощеная дорога
#
# WoodDeckSF: Площадь деревянного настила в квадратных футах
#
# OpenPorchSF: Площадь открытого крыльца в квадратных футах
#
# EnclosedPorch: Площадь закрытого крыльца в квадратных футах
#
# 3SsnPorch: Площадь трехсезонной веранды в квадратных футах
#
# ScreenPorch: Площадь крыльца с экраном в квадратных футах
#
# PoolArea: Площадь бассейна в квадратных футах
#
# PoolQC: Качество бассейна
#
# Fence: Качество ограждения
#
# MiscFeature: Различные характеристики, не включенные в другие категории
#
# MiscVal: $ Стоимость различных характеристик
#
# MoSold: Проданный месяц
#
# YrSold: Год продажи
#
# SaleType: Тип продажи
#
# SaleCondition: Состояние продажи

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import norm
from sklearn.model_selection import train_test_split
from scipy import stats
from scipy.stats import norm, skew 
from scipy.special import boxcox1p
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import max_error, mean_absolute_error, mean_absolute_percentage_error

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LassoCV
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import median_absolute_error
import math

# %%
df_train_1 = pd.read_csv("../input/house-prices-advanced-regression-techniques/train.csv", index_col=0)
df_train_1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df_test_1 = pd.read_csv("../input/house-prices-advanced-regression-techniques/test.csv", index_col=0)
df_test_1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# ...

# %%
df_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df_test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1455 non-null   object
#  2   LotFrontage    1232 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          107 non-null    object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
df_train_1.duplicated().sum()
# Out:
# 0

# %%
df_train_1['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=[10,8])
n, bins, patches = plt.hist(x=df_train_1['SalePrice'], bins='auto', color='#0504aa',
                            alpha=0, rwidth=0.85)
g = sns.histplot(df_train_1.SalePrice, color='#ff7518', kde = True)
plt.grid(axis='y', alpha=1.0)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('SalePrice Histogram')
plt.show()

# %% [markdown]
# # **Работа по анализу и очистки - training sample**

# %%
pd.options.display.max_rows=None 
df_train_1.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
def check_missed_values(df_train_1):
    df_train_1_na = (df_train_1.isnull().sum() / len(df_train_1)) * 100
    df_train_1_na = df_train_1_na.drop(df_train_1_na[df_train_1_na == 0].index).sort_values(ascending=False)
    missing_data_train = pd.DataFrame({'Missing Ratio' :df_train_1_na})
    return missing_data_train

# %%
missing_data_train = check_missed_values(df_train_1)
missing_data_train.head(20)
# Out:
#               Missing Ratio
# PoolQC            99.520548
# MiscFeature       96.301370
# Alley             93.767123
# Fence             80.753425
# FireplaceQu       47.260274
# LotFrontage       17.739726
# GarageType         5.547945
# GarageYrBlt        5.547945
# GarageFinish       5.547945
# GarageQual         5.547945
# GarageCond         5.547945
# BsmtExposure       2.602740
# BsmtFinType2       2.602740
# BsmtFinType1       2.534247
# BsmtCond           2.534247
# BsmtQual           2.534247
# MasVnrArea         0.547945
# MasVnrType         0.547945
# Electrical         0.068493

# %%
plt.figure(figsize = (16,5))
plt.xticks(rotation='90')
ax = sns.barplot(x = missing_data_train.index , y = missing_data_train["Missing Ratio"] )

# %%
df_train_1.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
df_train_1.shape
# Out:
# (1460, 75)

# %%
df_train_1.loc[df_train_1['LotFrontage'].isnull()==True,'LotFrontage']=70.0
df_train_1.loc[df_train_1['GarageYrBlt'].isnull()==True,'GarageYrBlt']=1979.0
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df_train_1[col] = df_train_1[col].fillna('None')
for col in ('BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual'):
    df_train_1[col] = df_train_1[col].fillna('None')
df_train_1.loc[df_train_1['MasVnrArea'].isnull()==True,'MasVnrArea']=103.0
df_train_1["MasVnrType"] = df_train_1["MasVnrType"].fillna("None")
df_train_1["Electrical"] = df_train_1["Electrical"].fillna("None")

# %%
missing_data = check_missed_values(df_train_1)
missing_data.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df_train_1.drop('SalePrice',axis=1).corr(),cmap="PiYG",annot=True)
plt.show()

# %%
dtype_objects = list(columns for columns in df_train_1.select_dtypes([object]).columns)

# %%
dtype_objects
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
plt.figure(figsize=(15,150))
plotnumber=1
for c in dtype_objects:
    ax=plt.subplot(20,2,plotnumber)
    b= sns.countplot(x=df_train_1[c],palette='Set3')
    plt.xticks(rotation=70)
    plotnumber+=1
    for bar in b.patches:
        b.annotate(format(bar.get_height()),
            (bar.get_x() + bar.get_width() / 2,
            bar.get_height()), ha='center', va='center',
            size=10, xytext=(0, 6),textcoords='offset points')
plt.show()

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_features = []
for numerical_feature in df_train_1.columns:
    if df_train_1[numerical_feature].dtype in numeric_dtypes:
        numerical_features.append(numerical_feature)
        
plot , ax = plt.subplots(12,3 , figsize = (20 , 90))
for index in range(len(numerical_features)-1):
    sns.scatterplot(data = df_train_1 , y = "SalePrice" , x = numerical_features[index] , alpha=0.4 , ax = ax[math.floor(index/3)][index%3])
plt.show()

# %%
df_train_1['LotFrontage'].describe()
# Out:
# count    1460.000000
# mean       70.041096
# std        22.024031
# min        21.000000
# 25%        60.000000
# 50%        70.000000
# 75%        79.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["LotFrontage"] >250)
sns.scatterplot(data = df_train_1 ,x = "LotFrontage", y = "SalePrice" , c = ["red" if is_outlier else "green" for is_outlier in outliers] ,ax = ax[0])
df_train_1.drop(df_train_1[df_train_1["LotFrontage"] >250].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "LotFrontage", y = "SalePrice", ax = ax[1] , c = ["green"])
plt.show()

# %%
df_train_1['LotArea'].describe()
# Out:
# count      1458.000000
# mean      10468.471879
# std        9879.455077
# min        1300.000000
# 25%        7544.500000
# 50%        9475.000000
# 75%       11600.000000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["LotArea"] >= 100000)
sns.scatterplot(data = df_train_1 ,x = "LotArea", y = "SalePrice" ,  c = ["red" if is_outlier else "green" for is_outlier in outliers] ,ax = ax[0])
df_train_1.drop(df_train_1[ (df_train_1["LotArea"] >= 100000)].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "LotArea", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['OverallQual'].describe()
# Out:
# count    1454.000000
# mean        6.095598
# std         1.381151
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["OverallQual"] == 10) & (df_train_1["SalePrice"] <= 250000)
sns.scatterplot(data = df_train_1 ,x = "OverallQual", y = "SalePrice", c = ["red" if is_outlier else "green" for is_outlier in outliers] ,ax = ax[0])
df_train_1.drop(df_train_1[(df_train_1["OverallQual"] == 10) & (df_train_1["SalePrice"] <=250000)].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "OverallQual", y = "SalePrice", ax = ax[1] , c = ["green"])
plt.show()

# %%
df_train_1['YearBuilt'].describe()
# Out:
# count    1453.000000
# mean     1971.243634
# std        30.241381
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["YearBuilt"] < 1900) & (df_train_1["SalePrice"] >= 400000)
sns.scatterplot(data = df_train_1 ,x = "YearBuilt", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "YearBuilt", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['YearRemodAdd'].describe()
# Out:
# count    1452.000000
# mean     1984.814050
# std        20.649579
# min      1950.000000
# 25%      1967.000000
# 50%      1994.000000
# 75%      2004.000000
# max      2010.000000
# Name: YearRemodAdd, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["YearRemodAdd"] < 1900) & (df_train_1["SalePrice"] >= 400000)
sns.scatterplot(data = df_train_1 ,x = "YearRemodAdd", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "YearRemodAdd", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['1stFlrSF'].describe()
# Out:
# count    1452.000000
# mean     1156.401515
# std       370.516966
# min       334.000000
# 25%       882.000000
# 50%      1085.500000
# 75%      1383.000000
# max      3228.000000
# Name: 1stFlrSF, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["1stFlrSF"] > 2700)
sns.scatterplot(data = df_train_1 ,x = "1stFlrSF", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "1stFlrSF", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['2ndFlrSF'].describe()
# Out:
# count    1450.000000
# mean      346.024828
# std       434.938109
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       728.000000
# max      2065.000000
# Name: 2ndFlrSF, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["2ndFlrSF"] > 2200)
sns.scatterplot(data = df_train_1 ,x = "2ndFlrSF", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "2ndFlrSF", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['TotalBsmtSF'].describe()
# Out:
# count    1450.000000
# mean     1049.255172
# std       410.291976
# min         0.000000
# 25%       795.000000
# 50%       990.000000
# 75%      1287.500000
# max      3206.000000
# Name: TotalBsmtSF, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["TotalBsmtSF"] > 3300)
sns.scatterplot(data = df_train_1 ,x = "TotalBsmtSF", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "TotalBsmtSF", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['GrLivArea'].describe()
# Out:
# count    1450.000000
# mean     1505.286897
# std       502.129333
# min       334.000000
# 25%      1128.000000
# 50%      1456.000000
# 75%      1768.000000
# max      4476.000000
# Name: GrLivArea, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["GrLivArea"] > 4500)
sns.scatterplot(data = df_train_1 ,x = "GrLivArea", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "GrLivArea", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1['GarageArea'].describe()
# Out:
# count    1450.000000
# mean      471.395172
# std       212.397694
# min         0.000000
# 25%       327.250000
# 50%       478.000000
# 75%       576.000000
# max      1390.000000
# Name: GarageArea, dtype: float64

# %%
plot , ax = plt.subplots(1 , 2 , figsize = (12 , 5))
outliers = (df_train_1["GarageArea"] > 1500)
sns.scatterplot(data = df_train_1 ,x = "GarageArea", y = "SalePrice" ,c = ["red" if is_outlier else "green" for is_outlier in outliers] ,  ax = ax[0])
df_train_1.drop(df_train_1[outliers].index , inplace = True)
sns.scatterplot(data = df_train_1 ,x = "GarageArea", y = "SalePrice", ax = ax[1], c = ["green"])
plt.show()

# %%
df_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 1 to 1460
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1450 non-null   int64
#  1   MSZoning       1450 non-null   object
#  2   LotFrontage    1450 non-null   float64
#  3   LotArea        1450 non-null   int64
#  4   Street         1450 non-null   object
#  5   LotShape       1450 non-null   object
#  6   LandContour    1450 non-null   object
#  7   Utilities      1450 non-null   object
#  8   LotConfig      1450 non-null   object
#  9   LandSlope      1450 non-null   object
#  10  Neighborhood   1450 non-null   object
#  11  Condition1     1450 non-null   object
#  12  Condition2     1450 non-null   object
#  13  BldgType       1450 non-null   object
#  14  HouseStyle     1450 non-null   object
#  15  OverallQual    1450 non-null   int64
#  16  OverallCond    1450 non-null   int64
# ...

# %%
numerical_features_train = df_train_1.dtypes[df_train_1.dtypes != 'object'].index
skewed_features_train = df_train_1[numerical_features_train].apply(lambda x: skew(x.dropna())).sort_values(ascending = False)
skewness_train = pd.DataFrame({'skew':skewed_features_train})
skewness_train
# Out:
#                     skew
# MiscVal        24.435637
# PoolArea       15.888245
# 3SsnPorch      10.257488
# LowQualFinSF    9.160950
# KitchenAbvGr    4.466174
# BsmtFinSF2      4.291410
# BsmtHalfBath    4.114759
# ScreenPorch     4.081912
# LotArea         3.979761
# EnclosedPorch   3.100113
# MasVnrArea      2.700582
# OpenPorchSF     2.344806
# SalePrice       1.902740
# WoodDeckSF      1.522531
# MSSubClass      1.400681
# GrLivArea       0.985837
# BsmtUnfSF       0.913856
# 2ndFlrSF        0.805425
# BsmtFinSF1      0.773844
# 1stFlrSF        0.765445
# LotFrontage     0.734384
# OverallCond     0.685501
# HalfBath        0.673763
# TotRmsAbvGrd    0.651684
# Fireplaces      0.636244
# BsmtFullBath    0.579260
# TotalBsmtSF     0.440263
# BedroomAbvGr    0.215750
# MoSold          0.213768
# OverallQual     0.197041
# GarageArea      0.135811
# YrSold          0.093246
# FullBath        0.033673
# GarageCars     -0.337593
# YearRemodAdd   -0.500616
# YearBuilt      -0.608794
# ...

# %%
skewness_train = skewness_train[abs(skewness_train) > 0.85]
print("There are {} skewed numerical features to Box Cox transform".format(skewness_train.shape[0]))

skewed_features_train = skewness_train.index
lam = 0.15
for feat in skewed_features_train:
    df_train_1[feat] = boxcox1p(df_train_1[feat], lam)
# Out:
# There are 37 skewed numerical features to Box Cox transform

# %%
data_object_train = df_train_1.select_dtypes(include = "object").columns
print (data_object_train)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
LE = LabelEncoder()

for feat in data_object_train:
    df_train_1[feat] = LE.fit_transform(df_train_1[feat].astype(str))

# %%
df_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 1 to 1460
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1450 non-null   float64
#  1   MSZoning       1450 non-null   int64
#  2   LotFrontage    1450 non-null   float64
#  3   LotArea        1450 non-null   float64
#  4   Street         1450 non-null   int64
#  5   LotShape       1450 non-null   int64
#  6   LandContour    1450 non-null   int64
#  7   Utilities      1450 non-null   int64
#  8   LotConfig      1450 non-null   int64
#  9   LandSlope      1450 non-null   int64
#  10  Neighborhood   1450 non-null   int64
#  11  Condition1     1450 non-null   int64
#  12  Condition2     1450 non-null   int64
#  13  BldgType       1450 non-null   int64
#  14  HouseStyle     1450 non-null   int64
#  15  OverallQual    1450 non-null   float64
#  16  OverallCond    1450 non-null   float64
# ...

# %% [markdown]
# # **Работа по анализу и очистки - validation sample**

# %%
pd.options.display.max_rows=None 
df_test_1.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
def check_missed_values(df_test_1):
    df_test_1_na = (df_test_1.isnull().sum() / len(df_test_1)) * 100
    df_test_1_na = df_test_1_na.drop(df_test_1_na[df_test_1_na == 0].index).sort_values(ascending=False)
    missing_data_test = pd.DataFrame({'Missing Ratio' :df_test_1_na})
    return missing_data_test

# %%
missing_data_test = check_missed_values(df_test_1)
missing_data_test.head(35)
# Out:
#               Missing Ratio
# PoolQC            99.794380
# MiscFeature       96.504455
# Alley             92.666210
# Fence             80.123372
# FireplaceQu       50.034270
# LotFrontage       15.558602
# GarageCond         5.346127
# GarageYrBlt        5.346127
# GarageQual         5.346127
# GarageFinish       5.346127
# GarageType         5.209047
# BsmtCond           3.084304
# BsmtExposure       3.015764
# BsmtQual           3.015764
# BsmtFinType1       2.878684
# BsmtFinType2       2.878684
# MasVnrType         1.096642
# MasVnrArea         1.028101
# MSZoning           0.274160
# BsmtFullBath       0.137080
# BsmtHalfBath       0.137080
# Functional         0.137080
# Utilities          0.137080
# GarageCars         0.068540
# GarageArea         0.068540
# TotalBsmtSF        0.068540
# KitchenQual        0.068540
# BsmtUnfSF          0.068540
# BsmtFinSF2         0.068540
# BsmtFinSF1         0.068540
# Exterior2nd        0.068540
# Exterior1st        0.068540
# ...

# %%
plt.figure(figsize = (16,5))
plt.xticks(rotation='vertical')
ax = sns.barplot(x = missing_data_test.index , y = missing_data_test["Missing Ratio"] )

# %%
df_test_1.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'],axis=1,inplace=True)

# %%
df_test_1.shape
# Out:
# (1459, 74)

# %%
df_test_1.loc[df_test_1['LotFrontage'].isnull()==True,'LotFrontage']=69.0
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df_test_1[col] = df_test_1[col].fillna('None')
df_test_1.loc[df_test_1['GarageYrBlt'].isnull()==True,'GarageYrBlt']=1978.0
df_test_1.loc[df_test_1['GarageCars'].isnull()==True,'GarageCars']=2.0
df_test_1.loc[df_test_1['GarageArea'].isnull()==True,'GarageArea']=473.0
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df_test_1[col] = df_test_1[col].fillna('None')
df_test_1.loc[df_test_1['BsmtFullBath'].isnull()==True,'BsmtFullBath']=0.5
df_test_1.loc[df_test_1['BsmtHalfBath'].isnull()==True,'BsmtHalfBath']=0.1
df_test_1.loc[df_test_1['TotalBsmtSF'].isnull()==True,'TotalBsmtSF']=1046.0
df_test_1.loc[df_test_1['BsmtUnfSF'].isnull()==True,'BsmtUnfSF']=554.0
df_test_1.loc[df_test_1['BsmtFinSF1'].isnull()==True,'BsmtFinSF1']=439.0
df_test_1.loc[df_test_1['BsmtFinSF2'].isnull()==True,'BsmtFinSF2']=53.0
df_test_1["MasVnrType"] = df_test_1["MasVnrType"].fillna("None")
df_test_1.loc[df_test_1['MasVnrArea'].isnull()==True,'MasVnrArea']=101.0
df_test_1["MSZoning"] = df_test_1["MSZoning"].fillna("None")
df_test_1["Functional"] = df_test_1["Functional"].fillna("None")
df_test_1["Utilities"] = df_test_1["Utilities"].fillna("None")
df_test_1["KitchenQual"] = df_test_1["KitchenQual"].fillna("None")
df_test_1["Exterior1st"] = df_test_1["Exterior1st"].fillna("None")
df_test_1["Exterior2nd"] = df_test_1["Exterior2nd"].fillna("None")
df_test_1["SaleType"] = df_test_1["SaleType"].fillna("None")

# %%
missing_data_test = check_missed_values(df_train_1)
missing_data_test.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
numerical_features_test = df_test_1.dtypes[df_test_1.dtypes != 'object'].index
skewed_features_test = df_test_1[numerical_features_test].apply(lambda x: skew(x.dropna())).sort_values(ascending = False)
skewness_test = pd.DataFrame({'skew':skewed_features_test})
skewness_test
# Out:
#                     skew
# PoolArea       20.176117
# MiscVal        20.054543
# LowQualFinSF   16.150628
# 3SsnPorch      12.511336
# EnclosedPorch   4.664371
# KitchenAbvGr    4.074860
# BsmtFinSF2      4.038565
# ScreenPorch     3.784349
# BsmtHalfBath    3.777853
# LotArea         3.112013
# OpenPorchSF     2.685015
# MasVnrArea      2.543804
# WoodDeckSF      2.128569
# 1stFlrSF        1.556592
# MSSubClass      1.345305
# BsmtFinSF1      1.164877
# GrLivArea       1.129240
# BsmtUnfSF       0.919286
# 2ndFlrSF        0.911944
# TotRmsAbvGrd    0.841731
# Fireplaces      0.819015
# TotalBsmtSF     0.813031
# HalfBath        0.713993
# LotFrontage     0.709861
# BsmtFullBath    0.648948
# OverallCond     0.448703
# BedroomAbvGr    0.436174
# GarageArea      0.300031
# FullBath        0.295534
# MoSold          0.182834
# OverallQual     0.181010
# YrSold          0.168813
# GarageCars     -0.107659
# GarageYrBlt    -0.164335
# YearRemodAdd   -0.399495
# YearBuilt      -0.587052

# %%
skewness_test = skewness_test[abs(skewness_test) > 0.85]
print("There are {} skewed numerical features to Box Cox transform".format(skewness_test.shape[0]))

skewed_features_test = skewness_test.index
lam = 0.15
for feat in skewed_features_test:
    df_test_1[feat] = boxcox1p(df_test_1[feat], lam)
# Out:
# There are 36 skewed numerical features to Box Cox transform

# %%
data_object_test = df_test_1.select_dtypes(include = "object").columns
print (data_object_test)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
LE = LabelEncoder()

for feat in data_object_test:
    df_test_1[feat] = LE.fit_transform(df_test_1[feat].astype(str))

# %%
df_test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   float64
#  1   MSZoning       1459 non-null   int64
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   Street         1459 non-null   int64
#  5   LotShape       1459 non-null   int64
#  6   LandContour    1459 non-null   int64
#  7   Utilities      1459 non-null   int64
#  8   LotConfig      1459 non-null   int64
#  9   LandSlope      1459 non-null   int64
#  10  Neighborhood   1459 non-null   int64
#  11  Condition1     1459 non-null   int64
#  12  Condition2     1459 non-null   int64
#  13  BldgType       1459 non-null   int64
#  14  HouseStyle     1459 non-null   int64
#  15  OverallQual    1459 non-null   float64
#  16  OverallCond    1459 non-null   float64
# ...

# %% [markdown]
# ## **Модель**

# %% [markdown]
# **Linear Regression**

# %%
x=df_train_1.drop(['SalePrice'],axis=1)
y=df_train_1['SalePrice']

# %%
from sklearn.preprocessing import MinMaxScaler
mc=MinMaxScaler()
scaled_x=mc.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_x,y,test_size=0.50,random_state=50)

# %%
x_train.shape
# Out:
# (725, 74)

# %%
x_test.shape
# Out:
# (725, 74)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)  

x_test_pred_LR = LR.predict(x_test)

# %%
x_test_pred_LR
# Out:
# array([30.689228  , 36.65310419, 37.54502441, 38.35579382, 29.20083842,
#        33.82722272, 30.90099787, 38.79431473, 33.5511528 , 31.52752968,
#        35.5120897 , 34.48259316, 33.01214652, 34.40745323, 34.03006311,
#        35.15045506, 35.70246702, 32.68305752, 37.4237174 , 29.96339326,
#        31.89054076, 35.54226806, 34.89994819, 33.87354175, 32.83901835,
#        35.12568776, 37.06270294, 37.75670296, 34.46413087, 34.90084198,
#        30.5253512 , 34.18060052, 37.04235907, 32.43851184, 33.94209529,
#        38.86722806, 37.03654015, 33.64233225, 32.84901085, 37.55515542,
#        31.02699916, 35.15493406, 37.97060281, 34.45270559, 34.74155284,
#        29.47488854, 35.85717071, 31.9430064 , 32.6771894 , 36.4625828 ,
#        31.87343027, 32.93118076, 35.20019217, 31.83926857, 32.35050628,
#        31.80588452, 31.37644496, 32.83205935, 32.47071905, 33.20352042,
#        32.93665168, 32.36570756, 32.81516239, 36.21105902, 35.32578141,
# ...

# %%
y_test
# Out:
# Id
# 1144    29.588763
# 765     36.845784
# 596     37.947989
# 168     38.085741
# 399     28.637091
# 1352    33.964429
# 1433    28.436291
# 1443    37.756878
# 492     32.461273
# 1401    31.862221
# 632     35.221047
# 1069    33.229214
# 1276    32.635573
# 625     33.752832
# 263     33.213385
# 803     34.579003
# 338     35.354791
# 1368    32.191277
# 764     38.316852
# 936     29.581961
# 180     30.822811
# 1107    34.274836
# 865     36.361314
# 161     33.654877
# 663     31.362625
# 959     34.446871
# 1254    37.405161
# 982     38.296804
# 972     34.035360
# 1345    33.402371
# 288     30.110806
# 564     34.446871
# 964     36.057018
# 681     32.889081
# 212     34.480130
# 645     38.967863
# 325     36.137034
# 912     32.909797
# 722     32.889081
# 1110    37.083799
# 354     31.146561
# 502     35.719755
# 655     38.572973
# 1142    34.852071
# 316     34.562617
# 916     29.239480
# 520     35.921741
# 50      32.191277
# 646     32.899447
# ...

# %%
x_train_pred_LR = LR.predict(x_train) 

x_train_pred_LR
# Out:
# array([32.71684092, 36.97379745, 32.02892986, 38.03902952, 36.58412225,
#        33.02169029, 34.81076666, 32.44967067, 31.22217112, 34.8627566 ,
#        33.94430792, 37.3345916 , 36.77259228, 35.57633862, 33.88175275,
#        32.09965865, 33.11650619, 33.29335549, 37.71104552, 32.15550821,
#        37.48179367, 31.5975938 , 35.86979182, 34.5473478 , 32.16207243,
#        34.24711701, 32.74483295, 38.09266544, 28.17758656, 35.15250328,
#        30.19640252, 33.71032135, 30.06839582, 31.2983875 , 36.52457292,
#        39.18037482, 33.17803755, 33.24274813, 33.88292757, 37.08416004,
#        35.77526517, 34.75744775, 31.8322471 , 32.92508182, 31.2327551 ,
#        35.86711429, 32.08146408, 33.74545487, 38.80472632, 33.28651141,
#        31.64370185, 33.89320172, 33.9344732 , 35.66821446, 35.45321703,
#        37.66871575, 36.30930636, 35.23955273, 32.63215062, 34.76429784,
#        37.19870651, 35.6659118 , 40.39360874, 34.14565181, 33.38031   ,
# ...

# %%
y_train
# Out:
# Id
# 1432    32.920131
# 317     36.600155
# 1340    32.259776
# 481     38.093488
# 142     36.600155
# 1027    33.838587
# 1252    33.991111
# 544     32.461273
# 1216    32.098867
# 295     33.820427
# 1152    33.169672
# 1045    37.036781
# 190     37.223161
# 238     34.756855
# 194     32.327599
# 1446    32.282458
# 301     33.447161
# 756     34.017693
# 410     38.371723
# 9       32.323098
# 160     37.968940
# 1121    31.784724
# 788     35.894391
# 1318    35.203030
# 771     32.544613
# 253     34.035360
# 980     32.721107
# 746     37.534497
# 711     27.320151
# 472     34.611664
# 971     32.548972
# 498     34.413459
# 1280    28.746773
# 723     32.075568
# 919     36.030156
# 162     39.701774
# 780     32.548972
# 296     32.868305
# 1081    32.971576
# 1066    38.134571
# 1122    35.322320
# 829     34.446871
# 1095    32.282458
# 270     33.093522
# 1105    31.151915
# 163     35.529446
# 506     32.075568
# 509     33.598827
# 1059    38.276706
# ...

# %%
x_train_pred_LR = LR.predict(x_train)
x_test_pred_LR = LR.predict(x_test)  

print("TRAIN")
print(f"MAX ERROR: {max_error(y_train, x_train_pred_LR)}")
print(f"MAE:       {mean_absolute_error(y_train, x_train_pred_LR)}")
print("TEST")
print(f"MAX ERROR: {max_error(y_test, x_test_pred_LR)}")
print(f"MAE:       {mean_absolute_error(y_test, x_test_pred_LR)}")
# Out:
# TRAIN
# MAX ERROR: 3.742428413834613
# MAE:       0.4798942746807069
# TEST
# MAX ERROR: 4.466013400947485
# MAE:       0.5632511395655985

# %%
print('Linear Regression trainind score is',LR.score(x_train,y_train))
# Out:
# Linear Regression trainind score is 0.929071916223895

# %%
print('Linear Regression testing score is',LR.score(x_test,y_test))
# Out:
# Linear Regression testing score is 0.8973200153022952

# %% [markdown]
# **Decision Tree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTR = DecisionTreeRegressor(max_depth=7)
DTR.fit(x_train,y_train)

x_DTR_train_predict = DTR.predict(x_train)
x_DTR_test_predict = DTR.predict(x_test)

print("TRAIN")
print(f"MAX ERROR: {max_error(y_train, x_DTR_train_predict)}")
print(f"MAE:       {mean_absolute_error(y_train, x_DTR_train_predict)}")
print("TEST")
print(f"MAX ERROR: {max_error(y_test, x_DTR_test_predict)}")
print(f"MAE:       {mean_absolute_error(y_test, x_DTR_test_predict)}")
# Out:
# TRAIN
# MAX ERROR: 1.929983435676938
# MAE:       0.3716670827983944
# TEST
# MAX ERROR: 7.2020451784681185
# MAE:       0.8951237015138855

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(
            DecisionTreeRegressor(),                
            param_grid = {                          
                'max_depth': range(1, 7),
                'min_samples_leaf': range(1, 30),
            },
            scoring = 'neg_mean_absolute_error',    
            cv = 5,                                 
            n_jobs = -1,                            
            return_train_score = True,              
            verbose = 10,                            
        )

grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 174 candidates, totalling 870 fits
# [CV 1/5; 1/174] START max_depth=1, min_samples_leaf=1...........................
# [CV 1/5; 1/174] END max_depth=1, min_samples_leaf=1;, score=(train=-1.342, test=-1.267) total time=   0.0s
# [CV 5/5; 1/174] START max_depth=1, min_samples_leaf=1...........................
# [CV 5/5; 1/174] END max_depth=1, min_samples_leaf=1;, score=(train=-1.305, test=-1.409) total time=   0.0s
# [CV 1/5; 2/174] START max_depth=1, min_samples_leaf=2...........................
# [CV 1/5; 2/174] END max_depth=1, min_samples_leaf=2;, score=(train=-1.342, test=-1.267) total time=   0.0s
# [CV 2/5; 2/174] START max_depth=1, min_samples_leaf=2...........................
# [CV 2/5; 2/174] END max_depth=1, min_samples_leaf=2;, score=(train=-1.373, test=-1.153) total time=   0.0s
# [CV 3/5; 2/174] START max_depth=1, min_samples_leaf=2...........................
# ...

# %%
print(f"Лучшая метрика:   {grid.best_score_}")
print(f"Лучшие параметры: {grid.best_params_}")
# Out:
# Лучшая метрика:   -0.8770654607643777
# Лучшие параметры: {'max_depth': 6, 'min_samples_leaf': 4}

# %%
x_GS_train_predict = grid.best_estimator_.predict(x_train)
x_GS_test_predict = grid.best_estimator_.predict(x_test)

print("TRAIN")
print(f"MAX ERROR: {max_error(y_train, x_GS_train_predict)}")
print(f"MAE:       {mean_absolute_error(y_train, x_GS_train_predict)}")
print("TEST")
print(f"MAX ERROR: {max_error(y_test, x_GS_test_predict)}")
print(f"MAE:       {mean_absolute_error(y_test, x_GS_test_predict)}")
# Out:
# TRAIN
# MAX ERROR: 2.595539961886594
# MAE:       0.5405885262532856
# TEST
# MAX ERROR: 5.626224675189551
# MAE:       0.879971592111362

# %%
x_DTR_test_predict
# Out:
# array([32.45122496, 36.67655914, 36.67655914, 37.57695201, 31.78507537,
#        33.99417242, 31.08599346, 37.57695201, 32.98794904, 31.04959995,
#        35.43049605, 36.25634198, 32.70333775, 33.99417242, 32.51316128,
#        34.57176664, 36.09232035, 32.98794904, 38.37669239, 25.8769943 ,
#        31.78507537, 34.57176664, 34.57176664, 33.16721398, 33.99417242,
#        34.57176664, 36.76070718, 38.37669239, 35.14208767, 34.57176664,
#        31.52130933, 33.99417242, 35.5294456 , 32.51316128, 33.16721398,
#        37.57695201, 36.76070718, 32.98794904, 32.51316128, 37.57695201,
#        32.55696684, 35.14208767, 41.08552098, 32.70333775, 34.57176664,
#        29.60566767, 36.71140721, 32.51316128, 32.51316128, 36.67655914,
#        31.30201133, 32.51316128, 35.03438198, 30.63038761, 32.70333775,
#        32.70333775, 32.55696684, 33.16721398, 34.67662977, 33.16721398,
#        32.51316128, 33.16721398, 32.51316128, 36.67655914, 35.14208767,
# ...

# %%
y_test
# Out:
# Id
# 1144    29.588763
# 765     36.845784
# 596     37.947989
# 168     38.085741
# 399     28.637091
# 1352    33.964429
# 1433    28.436291
# 1443    37.756878
# 492     32.461273
# 1401    31.862221
# 632     35.221047
# 1069    33.229214
# 1276    32.635573
# 625     33.752832
# 263     33.213385
# 803     34.579003
# 338     35.354791
# 1368    32.191277
# 764     38.316852
# 936     29.581961
# 180     30.822811
# 1107    34.274836
# 865     36.361314
# 161     33.654877
# 663     31.362625
# 959     34.446871
# 1254    37.405161
# 982     38.296804
# 972     34.035360
# 1345    33.402371
# 288     30.110806
# 564     34.446871
# 964     36.057018
# 681     32.889081
# 212     34.480130
# 645     38.967863
# 325     36.137034
# 912     32.909797
# 722     32.889081
# 1110    37.083799
# 354     31.146561
# 502     35.719755
# 655     38.572973
# 1142    34.852071
# 316     34.562617
# 916     29.239480
# 520     35.921741
# 50      32.191277
# 646     32.899447
# ...

# %%
x_DTR_train_predict
# Out:
# array([32.51316128, 36.20215153, 32.51316128, 37.57695201, 36.09232035,
#        32.70333775, 34.57176664, 32.46127271, 32.51316128, 35.03438198,
#        34.04220677, 37.03678058, 37.57695201, 35.14208767, 32.37246587,
#        32.51316128, 32.98794904, 33.99417242, 37.57695201, 32.37246587,
#        38.13125366, 31.78507537, 35.89439069, 34.57176664, 32.51316128,
#        33.99417242, 33.16721398, 37.29514281, 27.3201505 , 35.14208767,
#        32.54897168, 34.42708037, 28.17703476, 31.52130933, 36.20215153,
#        39.91728695, 32.51316128, 33.16721398, 33.16721398, 38.13125366,
#        35.14208767, 34.04220677, 32.51316128, 33.16721398, 32.70333775,
#        36.09232035, 32.70333775, 33.90425503, 37.57695201, 33.99417242,
#        32.37246587, 32.98794904, 32.98794904, 35.14208767, 35.49292964,
#        37.57695201, 36.67655914, 34.36470582, 32.70333775, 35.14208767,
#        36.67655914, 36.09232035, 42.52426408, 34.57176664, 34.04220677,
# ...

# %%
y_train
# Out:
# Id
# 1432    32.920131
# 317     36.600155
# 1340    32.259776
# 481     38.093488
# 142     36.600155
# 1027    33.838587
# 1252    33.991111
# 544     32.461273
# 1216    32.098867
# 295     33.820427
# 1152    33.169672
# 1045    37.036781
# 190     37.223161
# 238     34.756855
# 194     32.327599
# 1446    32.282458
# 301     33.447161
# 756     34.017693
# 410     38.371723
# 9       32.323098
# 160     37.968940
# 1121    31.784724
# 788     35.894391
# 1318    35.203030
# 771     32.544613
# 253     34.035360
# 980     32.721107
# 746     37.534497
# 711     27.320151
# 472     34.611664
# 971     32.548972
# 498     34.413459
# 1280    28.746773
# 723     32.075568
# 919     36.030156
# 162     39.701774
# 780     32.548972
# 296     32.868305
# 1081    32.971576
# 1066    38.134571
# 1122    35.322320
# 829     34.446871
# 1095    32.282458
# 270     33.093522
# 1105    31.151915
# 163     35.529446
# 506     32.075568
# 509     33.598827
# 1059    38.276706
# ...

# %%
print('Training score for Decision Tree Regressor is',DTR.score(x_train,y_train))
# Out:
# Training score for Decision Tree Regressor is 0.9548717066924463

# %%
print('Testing score for Decision Tree Regressor is',DTR.score(x_test,y_test))
# Out:
# Testing score for Decision Tree Regressor is 0.7168940858957584

# %% [markdown]
# **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFR = RandomForestRegressor(n_estimators=500, max_depth=6)
RFR.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, n_estimators=500)

# %%
x_RFR_train_predict = RFR.predict(x_train)
x_RFR_test_predict = RFR.predict(x_test)

# %%
print("TRAIN")
print(f"MAX ERROR: {max_error(y_train, x_RFR_train_predict)}")
print(f"MAE:       {mean_absolute_error(y_train, x_RFR_train_predict)}")
print("TEST")
print(f"MAX ERROR: {max_error(y_test, x_RFR_test_predict)}")
print(f"MAE:       {mean_absolute_error(y_test, x_RFR_test_predict)}")
# Out:
# TRAIN
# MAX ERROR: 2.3519098726116
# MAE:       0.41266139432369164
# TEST
# MAX ERROR: 5.062473578048429
# MAE:       0.6589042254634448

# %%
from sklearn.model_selection import RandomizedSearchCV

grid = RandomizedSearchCV(
            RandomForestRegressor(),                
            param_distributions = {                 
                'max_depth': range(6, 20),
                'min_samples_split': range(2, 9),
                'max_features': range(2, 11)
            },
            scoring = 'neg_mean_absolute_error',   
            cv = 3,                                 
            n_jobs = -1,                            
            return_train_score = True,              
            n_iter=16,                              
            verbose = 5,                            
        )

grid.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
#
# [CV 3/5; 146/174] START max_depth=6, min_samples_leaf=1.........................
# [CV 3/5; 146/174] END max_depth=6, min_samples_leaf=1;, score=(train=-0.479, test=-0.993) total time=   0.0s
# [CV 4/5; 146/174] START max_depth=6, min_samples_leaf=1.........................
# [CV 4/5; 146/174] END max_depth=6, min_samples_leaf=1;, score=(train=-0.480, test=-0.891) total time=   0.0s
# [CV 5/5; 146/174] START max_depth=6, min_samples_leaf=1.........................
# [CV 5/5; 146/174] END max_depth=6, min_samples_leaf=1;, score=(train=-0.478, test=-1.011) total time=   0.0s
# [CV 1/5; 147/174] START max_depth=6, min_samples_leaf=2.........................
# [CV 1/5; 147/174] END max_depth=6, min_samples_leaf=2;, score=(train=-0.489, test=-0.824) total time=   0.0s
# [CV 2/5; 147/174] START max_depth=6, min_samples_leaf=2.........................
# ...

# %%
print(f"Лучшая метрика:   {grid.best_score_}")
print(f"Лучшие параметры: {grid.best_params_}")
# Out:
# Лучшая метрика:   -0.5843393514422036
# Лучшие параметры: {'min_samples_split': 8, 'max_features': 10, 'max_depth': 19}

# %%
x_GS_train_predict = grid.best_estimator_.predict(x_train)
x_GS_test_predict = grid.best_estimator_.predict(x_test)

print("TRAIN")
print(f"MAX ERROR: {max_error(y_train, x_GS_train_predict)}")
print(f"MAE:       {mean_absolute_error(y_train, x_GS_train_predict)}")
print("TEST")
print(f"MAX ERROR: {max_error(y_test, x_GS_test_predict)}")
print(f"MAE:       {mean_absolute_error(y_test, x_GS_test_predict)}")
# Out:
# TRAIN
# MAX ERROR: 2.610934840764642
# MAE:       0.31146712751736294
# TEST
# MAX ERROR: 4.697969634092228
# MAE:       0.5823548671793077

# %%
print('Training score for Random Forest Regressor Hyper Parametric Tuning is ',RFR.score(x_train,y_train))
# Out:
# Training score for Random Forest Regressor Hyper Parametric Tuning is  0.9504204635544629

# %%
print('Training score for Random Forest Regressor Hyper Parametric Tuning is ',RFR.score(x_test,y_test))
# Out:
# Training score for Random Forest Regressor Hyper Parametric Tuning is  0.8482217025947535

# %% [markdown]
# **Xtreme Gradient Boosting**

# %%
from xgboost import XGBRegressor

# %%
XGB = XGBRegressor()
XGB.fit(x_train,y_train) 

x_test_XGB_pred = XGB.predict(x_test)

# %%
x_test_XGB_pred
# Out:
# array([31.294682, 36.344276, 37.699154, 39.07137 , 29.360302, 33.606487,
#        31.356215, 37.37733 , 33.023857, 31.819992, 36.195366, 33.220078,
#        31.989237, 33.592934, 33.519978, 34.502453, 35.29014 , 33.05907 ,
#        38.475075, 30.200222, 31.767014, 34.43177 , 35.072662, 33.504913,
#        31.728569, 34.649887, 36.537617, 38.06067 , 34.348972, 34.134663,
#        31.249035, 33.99414 , 37.424305, 32.120174, 33.587727, 37.07013 ,
#        36.10027 , 32.607796, 32.877045, 37.475643, 30.802006, 35.117554,
#        39.128746, 34.25481 , 34.19031 , 29.619595, 36.30915 , 32.276455,
#        32.2962  , 36.653625, 31.73245 , 32.12614 , 33.429977, 32.798573,
#        32.577293, 32.356106, 31.965963, 32.64345 , 32.658295, 32.870678,
#        32.30791 , 32.439682, 32.96642 , 37.223988, 35.668266, 32.276623,
#        32.222805, 33.229248, 36.184624, 35.78266 , 35.04744 , 33.720783,
#        34.468403, 30.827913, 36.661327, 34.913418, 31.782114, 34.87217 ,
# ...

# %%
x_train_XGB_pred = XGB.predict(x_train)

# %%
x_train_XGB_pred
# Out:
# array([32.908047, 36.59611 , 32.25826 , 38.106457, 36.599773, 33.806202,
#        33.989647, 32.46217 , 32.089565, 33.813522, 33.172474, 37.031548,
#        37.21529 , 34.774395, 32.34359 , 32.277115, 33.456947, 34.045357,
#        38.35981 , 32.327553, 37.961018, 31.782497, 35.908577, 35.190052,
#        32.54636 , 34.03418 , 32.71493 , 37.53754 , 27.337523, 34.618946,
#        32.5439  , 34.40717 , 28.749166, 32.055733, 36.032272, 39.71027 ,
#        32.562332, 32.87204 , 32.98881 , 38.124264, 35.322968, 34.447945,
#        32.281574, 33.09701 , 31.18322 , 35.53569 , 32.07005 , 33.60278 ,
#        38.281254, 33.674026, 31.714722, 32.727562, 33.483047, 35.081543,
#        35.15658 , 37.1789  , 36.846245, 34.615627, 32.541595, 34.701714,
#        37.320084, 36.103317, 42.518154, 35.127235, 33.737774, 32.53666 ,
#        33.307144, 31.167856, 32.791508, 34.54144 , 34.12656 , 31.958286,
#        35.525623, 34.190754, 34.95947 , 31.339184, 36.10744 , 34.02638 ,
# ...

# %%
print('Training score for XGB is',XGB.score(x_train,y_train))
# Out:
# Training score for XGB is 0.9999586095906291

# %%
print('Training score for XGB is',XGB.score(x_test,y_test))
# Out:
# Training score for XGB is 0.8664879487148102

# %%
df_score_final = pd.Series(['LR', 'DTR', 'RFR', 'XGB'], [LR.score(x_train,y_train), DTR.score(x_train,y_train), RFR.score(x_train,y_train), XGB.score(x_train,y_train)])
df_score_final = pd.DataFrame(df_score_final)
df_score_final.reset_index()
df_score_final = {"Models":np.array(['LR', 'DTR', 'RFR', 'XGB']),
    "Accuracy_score": np.array([LR.score(x_train,y_train), DTR.score(x_train,y_train), RFR.score(x_train,y_train), XGB.score(x_train,y_train)])}
df_score_final = pd.DataFrame(df_score_final)
df_score_final
# Out:
#   Models  Accuracy_score
# 0     LR        0.929072
# 1    DTR        0.954872
# 2    RFR        0.950420
# 3    XGB        0.999959
